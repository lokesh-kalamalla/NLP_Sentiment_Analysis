# %%
import nltk
import pandas as pd

# %%
data=pd.read_csv("./tweet_emotions.csv")

# %%
import numpy as np
data = data.sample(frac=1)

# %%
data.pop("tweet_id")
# Out:
# 21158    1694182668
# 1570     1957342084
# 15590    1964887227
# 33736    1752698214
# 11767    1963346262
#             ...
# 14153    1964373635
# 3265     1957742079
# 1840     1957410705
# 36107    1753238307
# 33212    1752534638
# Name: tweet_id, Length: 40000, dtype: int64

# %%
print(data)
# Out:
#        sentiment                                            content
# 21158      worry  @jdpeterson I say the same about poems. When y...
# 1570     neutral  @arania nope i cant figure out how to get the ...
# 15590      worry  im getting really spotty and my spots ALWAYS s...
# 33736        fun  @mycaricature Keep the suggestions coming...I ...
# 11767    neutral  TGIF!! But I have so much work to do this weekend
# ...          ...                                                ...
# 14153    sadness  @lilyroseallen yes........there are many cool ...
# 3265    surprise                                    why am i awake?
# 1840     neutral                               i have much to learn
# 36107    neutral  had a nice time with juno  http://plurk.com/p/...
# 33212  happiness  @QueenofSpain Good night Erin!  i wouldn't say...
#
# [40000 rows x 2 columns]

# %%
data['content'] = data['content'].apply(lambda x: " ".join(x.lower() for x in x.split()))
print(data['content'])
# Out:
# 21158    @jdpeterson i say the same about poems. when y...
# 1570     @arania nope i cant figure out how to get the ...
# 15590    im getting really spotty and my spots always s...
# 33736    @mycaricature keep the suggestions coming...i ...
# 11767    tgif!! but i have so much work to do this weekend
#                                ...
# 14153    @lilyroseallen yes........there are many cool ...
# 3265                                       why am i awake?
# 1840                                  i have much to learn
# 36107    had a nice time with juno http://plurk.com/p/s...
# 33212    @queenofspain good night erin! i wouldn't say ...
# Name: content, Length: 40000, dtype: object

# %%
data=data.drop(data[data.sentiment=='anger'].index)
data=data.drop(data[data.sentiment=='enthusiasm'].index)
data=data.drop(data[data.sentiment=='boredom'].index)
data=data.drop(data[data.sentiment=='empty'].index)
data=data.drop(data[data.sentiment=='hate'].index)
data=data.drop(data[data.sentiment=='relief'].index)

# %%
print(data)
# Out:
#        sentiment                                            content
# 21158      worry  @jdpeterson i say the same about poems. when y...
# 1570     neutral  @arania nope i cant figure out how to get the ...
# 15590      worry  im getting really spotty and my spots always s...
# 33736        fun  @mycaricature keep the suggestions coming...i ...
# 11767    neutral  tgif!! but i have so much work to do this weekend
# ...          ...                                                ...
# 14153    sadness  @lilyroseallen yes........there are many cool ...
# 3265    surprise                                    why am i awake?
# 1840     neutral                               i have much to learn
# 36107    neutral  had a nice time with juno http://plurk.com/p/s...
# 33212  happiness  @queenofspain good night erin! i wouldn't say ...
#
# [35276 rows x 2 columns]

# %%
data=data.reset_index(drop=True)

print(data)
# Out:
#        sentiment                                            content
# 0          worry  @jdpeterson i say the same about poems. when y...
# 1        neutral  @arania nope i cant figure out how to get the ...
# 2          worry  im getting really spotty and my spots always s...
# 3            fun  @mycaricature keep the suggestions coming...i ...
# 4        neutral  tgif!! but i have so much work to do this weekend
# ...          ...                                                ...
# 35271    sadness  @lilyroseallen yes........there are many cool ...
# 35272   surprise                                    why am i awake?
# 35273    neutral                               i have much to learn
# 35274    neutral  had a nice time with juno http://plurk.com/p/s...
# 35275  happiness  @queenofspain good night erin! i wouldn't say ...
#
# [35276 rows x 2 columns]

# %%
sentiments=[]
for i in range(len(data)):
    if data.sentiment[i]=="worry":
        sentiments.append(1)

    elif data.sentiment[i]=="sadness":
        sentiments.append(2)
        
    elif data.sentiment[i]=="surprise":
        sentiments.append(3)
        
    elif data.sentiment[i]=="neutral":
        sentiments.append(4)
        
    elif data.sentiment[i]=="fun":
        sentiments.append(5)
        
    elif data.sentiment[i]=="love":    
        sentiments.append(6)
        
    elif data.sentiment[i]=="happiness":    
        sentiments.append(7)
        
print(sentiments)
# Out:
# [1, 4, 1, 5, 4, 1, 6, 7, 4, 5, 4, 3, 3, 1, 7, 1, 1, 6, 4, 1, 3, 2, 3, 3, 7, 6, 7, 2, 7, 5, 1, 2, 2, 4, 4, 5, 6, 7, 1, 6, 4, 3, 3, 2, 5, 4, 2, 6, 1, 1, 7, 4, 2, 6, 4, 4, 7, 4, 2, 5, 4, 1, 6, 4, 1, 5, 7, 1, 4, 1, 6, 6, 1, 4, 4, 6, 6, 4, 1, 6, 6, 6, 6, 2, 1, 2, 4, 4, 1, 2, 4, 1, 2, 7, 5, 2, 2, 5, 4, 3, 7, 1, 4, 4, 1, 7, 2, 2, 2, 6, 2, 2, 1, 2, 4, 7, 1, 7, 6, 4, 1, 4, 4, 2, 7, 1, 1, 1, 6, 4, 1, 2, 2, 5, 2, 7, 3, 7, 4, 4, 4, 7, 4, 4, 2, 5, 2, 7, 7, 4, 5, 4, 7, 1, 4, 1, 7, 4, 2, 7, 4, 1, 2, 1, 4, 2, 7, 2, 4, 2, 6, 2, 3, 4, 1, 2, 2, 4, 7, 4, 1, 6, 6, 4, 4, 2, 3, 5, 4, 1, 4, 1, 5, 4, 4, 6, 2, 4, 7, 3, 4, 4, 1, 7, 1, 7, 2, 4, 7, 4, 4, 7, 7, 1, 4, 7, 2, 7, 2, 2, 2, 4, 6, 2, 4, 6, 3, 7, 3, 1, 6, 1, 6, 2, 3, 4, 7, 4, 4, 6, 4, 7, 7, 1, 3, 1, 4, 5, 4, 5, 4, 4, 2, 1, 2, 7, 2, 1, 5, 1, 1, 4, 4, 2, 4, 7, 1, 1, 1, 2, 1, 2, 7, 5, 6, 1, 4, 2, 4, 2, 1, 1, 4, 4, 4, 1, 4, 7, 4, 4, 6, 3, 2, 1, 4, 4, 3, 1, 1, 4, 5, 7, 1, 7, 2, 1, 7, 2, 6, 4, 6, 4, 4, 6, 4, 6, 7, 1, 1, 2, 7, 6, 2, 4, 6, 1, 7, 1, 2, 4, 6, 2, 7
# ...

# %%
#########################################################

# %%
train_data=data[:32000]
test_data=data[32000:]

# %%
all_tweets=[]
for i in range(len(train_data)):
    all_tweets.append(train_data.content[i])

print(all_tweets)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sadness=[] 

for i in range(len(train_data)):
    if data.sentiment[i]=='sadness':
        sadness.append(train_data.content[i])

print(len(sadness))
# Out:
# 5047

# %%
surprise=[] 

for i in range(len(train_data)):
    if data.sentiment[i]=='surprise':
        surprise.append(train_data.content[i])

        
print(len(surprise))
# Out:
# 1982

# %%
worry=[] 

for i in range(len(train_data)):
    if data.sentiment[i]=='worry':
        worry.append(train_data.content[i])

        
print(len(worry))
# Out:
# 8062

# %%
neutral=[] 

for i in range(len(train_data)):
    if data.sentiment[i]=='neutral':
        neutral.append(train_data.content[i])

        
print(len(neutral))
# Out:
# 7771

# %%
fun=[]  
    
for i in range(len(train_data)):
    if data.sentiment[i]=='fun':
        fun.append(train_data.content[i])

        
print(len(fun))
# Out:
# 1544

# %%
happiness=[]   

for i in range(len(train_data)):
    if data.sentiment[i]=='happiness':
        happiness.append(train_data.content[i])

        
print(len(happiness))
# Out:
# 4360

# %%
love=[]     
for i in range(len(train_data)):
    if data.sentiment[i]=='love':
        love.append(train_data.content[i])

        
print(len(love))
# Out:
# 3234

# %%
biased=[(8062/32000),(5407/32000),(1982/32000),(7771/32000),(1544/32000),(3234/32000),(4360/32000)]

# %%
bias=biased.copy()

# %%
bias=np.array(bias)

# %%
bias=bias/np.sum(bias)*np.ones(7)

# %%
print(bias)
# Out:
# [0.24913473 0.167089   0.06124845 0.24014215 0.04771323 0.0999382
#  0.13473424]

# %%
import re
import string
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import numpy as np

# %%
from nltk.stem import PorterStemmer

stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]
stemmer = PorterStemmer()
stemmed_stopwords=[]
for i in stop_words:
    stem_word = stemmer.stem(i)
    stemmed_stopwords.append(stem_word)
    
print(stemmed_stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'our', 'ourselv', 'you', 'your', 'your', 'yourself', 'yourselv', 'he', 'him', 'hi', 'himself', 'she', 'her', 'her', 'herself', 'it', 'it', 'itself', 'they', 'them', 'their', 'their', 'themselv', 'what', 'which', 'who', 'whom', 'thi', 'that', 'these', 'those', 'am', 'is', 'are', 'wa', 'were', 'be', 'been', 'be', 'have', 'ha', 'had', 'have', 'do', 'doe', 'did', 'do', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'becaus', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'dure', 'befor', 'after', 'abov', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'onc', 'here', 'there', 'when', 'where', 'whi', 'how', 'all', 'ani', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'onli', 'own', 'same', 'so', 'than', 'too', 'veri', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']

# %%
######################################################################################

# %%
def process_tweet(tweet):
    
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    tweet = re.sub(r'\$\w*', '', tweet)
    
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    # remove hyperlinks
    
    tweet = re.sub(r'https?://[^\s\n\r]+', '', tweet)
    # remove hashtags
    
    tweet = re.sub(r'#', '', tweet)
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
    # print(tweet_tokens)

    tweets_clean = []
    for word in tweet_tokens:
        if (word not in stopwords_english and  # remove stopwords
            word not in string.punctuation and
           word not in stemmed_stopwords):  # remove punctuation
            # tweets_clean.append(word)
            stem_word = stemmer.stem(word)  # stemming word
            tweets_clean.append(stem_word)

    return tweets_clean

# %%
####################################################################################

# %%
def count_tweets(result, tweets, ys):
    
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            
            pair = (word,y)
            
            
            if pair in result:
                result[pair] += 1

            else:
                result[pair] = 1
  
    return result

# %%
result={}

pair_dic=count_tweets(result,all_tweets,sentiments)
print(pair_dic)
# Out:
# {('layin', 2): 1, ('n', 2): 38, ('bed', 2): 66, ('headach', 2): 37, ('ughhh', 2): 11, ('...', 2): 1065, ('waitin', 2): 3, ('call', 2): 65, ('funer', 2): 7, ('ceremoni', 2): 3, ('gloomi', 2): 7, ('friday', 2): 77, ('want', 4): 252, ('trade', 4): 4, ('someon', 4): 55, ('houston', 4): 2, ('ticket', 4): 17, ('one', 4): 305, ('re-ping', 1): 1, ('go', 1): 794, ('prom', 1): 16, ('bc', 1): 11, ('bf', 1): 4, ('like', 1): 456, ('friend', 1): 112, ('sleep', 2): 95, ('im', 2): 249, ('think', 2): 134, ('old', 2): 37, ('friend', 2): 110, ('want', 2): 233, ("he'", 2): 24, ('marri', 2): 6, ('damn', 2): 59, ('2', 2): 139, ('scandal', 2): 1, ('hmmm', 1): 25, ('charlen', 2): 1, ('love', 2): 152, ('miss', 2): 516, ("i'm", 2): 552, ('sorri', 2): 178, ('least', 2): 34, ('cant', 4): 63, ('fall', 4): 16, ('asleep', 4): 15, ('choke', 1): 1, ('retain', 1): 1, ('ugh', 2): 65, ('beat', 2): 7, ('stupid', 2): 52, ('song', 2): 37, ('get', 2): 392, ('next', 2): 62, ('rude', 2): 3, ('u', 2): 150, ('watch', 2): 106, 
# ...

# %%
def predict_class(test_tweet,pair_dic,bias):
  prob=[1,1,1,1,1,1,1]
  prob=np.array([[1,1,1,1,1,1,1]])
  l=np.ones(7)
  for i in test_tweet:
    l=[1,1,1,1,1,1,1]
    for j in pair_dic:
      if(i==j[0]):
        l[j[1]-1]+=pair_dic[j]*bias[j[1]-1]    
    div= sum(l)*np.ones(7)   
    l=np.array(l)
    l=l/div
    prob=np.multiply(prob,l)    
  return np.argmax(prob)+1

# %%
test_tweets=[]
for i in test_data["content"]:
  test_tweets.append(i)

# %%
print(test_data[676:679])
# Out:
#       sentiment                                            content
# 32676      love  sitting in mels house, just finished eating mc...
# 32677     worry  rblpnbro @dhair not quite where i need to be h...
# 32678     worry  shooould be sleeping already, but got caught u...

# %%
print(predict_class(process_tweet(test_tweets[677]),pair_dic,bias))
# Out:
# 1

# %%
preds=[]
for i in range(len(test_tweets)):
  preds.append(predict_class(process_tweet(test_tweets[i]),pair_dic,bias))
  print(i)

# %%
sum(1 for x,y in zip(sentiments[32000:],preds) if x == y) / float(len(preds))
# Out:
# 1.0

# %%
a=np.array(sentiments[32000:])
b=np.array(preds)
correct = (a == b)
accuracy = correct.sum() / correct.size
print(accuracy*100)
# Out:
# 31.990231990231987

# %%
p=0
for i in preds:
  if(i==1):
    p+=1

# %%
print(p)
# Out:
# 26

# %%
print(preds)
# Out:
# [7, 2, 7, 7, 7, 6, 6, 2, 6, 6, 7, 2, 6, 2, 6, 6, 7, 6, 7, 6, 7, 6, 7, 6, 7, 2, 7, 2, 7, 6, 6, 3, 7, 7, 7, 7, 6, 7, 7, 7, 7, 2, 2, 7, 7, 6, 1, 6, 1, 7, 7, 7, 3, 7, 2, 6, 7, 6, 6, 7, 7, 7, 7, 7, 2, 2, 7, 7, 6, 7, 6, 7, 7, 2, 7, 7, 2, 7, 7, 7, 7, 6, 4, 7, 7, 7, 7, 7, 6, 7, 7, 7, 7, 6, 7, 4, 7, 6, 7, 7, 6, 6, 7, 7, 2, 6, 7, 7, 7, 7, 7, 7, 2, 7, 7, 2, 6, 7, 7, 2, 2, 7, 7, 6, 7, 7, 2, 7, 6, 7, 7, 7, 7, 6, 6, 7, 7, 6, 7, 7, 7, 7, 5, 7, 7, 7, 5, 6, 6, 7, 6, 2, 7, 6, 7, 7, 6, 2, 7, 7, 7, 7, 7, 7, 6, 6, 2, 2, 1, 2, 7, 7, 7, 7, 2, 7, 7, 2, 7, 7, 6, 7, 7, 6, 6, 7, 7, 6, 7, 7, 7, 2, 6, 7, 7, 7, 7, 2, 3, 7, 7, 2, 7, 2, 7, 7, 6, 6, 7, 2, 7, 7, 7, 3, 5, 7, 2, 2, 6, 6, 7, 7, 7, 6, 7, 7, 7, 7, 7, 7, 5, 2, 7, 7, 7, 6, 7, 7, 7, 7, 7, 6, 6, 6, 7, 6, 6, 2, 2, 7, 7, 7, 7, 7, 7, 6, 2, 7, 7, 7, 7, 2, 7, 7, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 6, 6, 7, 7, 6, 7, 7, 6, 7, 7, 7, 6, 2, 7, 7, 6, 6, 6, 6, 2, 1, 7, 7, 4, 2, 7, 7, 6, 6, 7, 6, 7, 7, 6, 7, 2, 2, 7, 6, 7, 2, 6, 7, 7, 7, 6, 7, 6, 7, 6, 7, 6, 7, 2, 7, 1, 6
# ...

# %%
print(sentiments[32000:])
# Out:
# [4, 4, 7, 4, 6, 6, 4, 4, 2, 4, 7, 1, 5, 3, 3, 7, 7, 3, 6, 4, 6, 6, 7, 6, 4, 7, 7, 7, 5, 6, 5, 3, 4, 5, 2, 4, 4, 4, 4, 3, 4, 2, 7, 6, 4, 6, 7, 3, 2, 4, 7, 6, 3, 4, 7, 4, 7, 1, 7, 4, 7, 7, 5, 5, 1, 3, 7, 4, 7, 6, 4, 6, 5, 2, 1, 4, 1, 4, 6, 7, 7, 6, 4, 4, 4, 1, 5, 4, 6, 4, 2, 4, 3, 7, 7, 7, 7, 6, 3, 7, 6, 6, 5, 6, 4, 4, 6, 7, 1, 4, 7, 7, 6, 7, 4, 3, 4, 7, 1, 1, 1, 7, 4, 6, 4, 1, 2, 1, 4, 4, 7, 7, 7, 6, 4, 4, 5, 7, 7, 3, 7, 7, 1, 4, 1, 7, 7, 6, 6, 7, 4, 1, 6, 7, 3, 4, 6, 4, 1, 7, 1, 7, 2, 4, 7, 6, 1, 2, 4, 4, 5, 7, 7, 5, 4, 1, 5, 4, 7, 1, 6, 3, 4, 6, 3, 4, 3, 3, 4, 6, 6, 4, 5, 1, 7, 7, 4, 4, 4, 7, 4, 1, 7, 5, 5, 7, 7, 6, 3, 7, 4, 7, 4, 4, 4, 1, 4, 1, 6, 6, 6, 4, 7, 4, 7, 4, 3, 7, 1, 4, 7, 4, 6, 7, 5, 5, 3, 1, 6, 4, 7, 4, 6, 6, 7, 4, 6, 2, 7, 4, 4, 4, 4, 5, 4, 6, 1, 7, 4, 2, 5, 4, 4, 7, 6, 3, 7, 4, 7, 5, 1, 7, 4, 6, 1, 4, 6, 4, 4, 7, 1, 4, 7, 4, 4, 7, 1, 6, 4, 6, 4, 7, 4, 4, 4, 1, 4, 5, 4, 4, 4, 5, 3, 4, 4, 4, 6, 4, 5, 4, 7, 4, 3, 2, 1, 1, 4, 1, 7, 4, 4, 6, 7, 7, 4, 4, 4, 7, 7, 4, 7, 4, 6
# ...

# %%
print(train_data)
# Out:
#        sentiment                                            content
# 0        sadness  layin n bed with a headache ughhhh...waitin on...
# 1        sadness                funeral ceremony...gloomy friday...
# 2        neutral  @dannycastillo we want to trade with someone w...
# 3          worry  re-pinging @ghostridah14: why didn't you go to...
# 4        sadness  i should be sleep, but im not! thinking about ...
# ...          ...                                                ...
# 31995   surprise  @krazyfrog i got me to watch it. recommend som...
# 31996       love  @katyperry it's under a honeymoon by the good ...
# 31997  happiness  @paulbay1028 bit of a lie -in. eaten all the b...
# 31998    neutral  @talesfromthepit loved your blog from the musi...
# 31999       love             @therealsavannah today was fun &lt;333
#
# [32000 rows x 2 columns]

# %%
x_train = train_data['content']
y_train = train_data['sentiment']

x_test = test_data['content']
y_test = test_data['sentiment']

# %%
print(test_data)
# Out:
#        sentiment                                            content
# 32000       love         @mrskutcher you guys are an awesome couple
# 32001      worry  so disappointed about the talent lineup for &q...
# 32002    neutral  @russelldevon - not a heap hey. just bout tu h...
# 32003  happiness  @leeyecandy hahaha. i think you're pretty far ...
# 32004       love  it's those little things you do, that make me ...
# ...          ...                                                ...
# 35271    sadness  @lilyroseallen yes........there are many cool ...
# 35272   surprise                                    why am i awake?
# 35273    neutral                               i have much to learn
# 35274    neutral  had a nice time with juno http://plurk.com/p/s...
# 35275  happiness  @queenofspain good night erin! i wouldn't say ...
#
# [3276 rows x 2 columns]

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer(num_words=30000,
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
    lower=True,
    split=' ',
    oov_token='<OOV>')

# %%
tokenizer.fit_on_texts(x_train)

# %%
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)

# %%
x_train = tf.keras.utils.pad_sequences(
    x_train, padding="post", maxlen=7
)

x_test = tf.keras.utils.pad_sequences(
    x_test, padding="post", maxlen=7
)

# %%
Model = tf.keras.Sequential()

inputs = tf.keras.Input(shape=(None,), dtype="int64")
Model.add(tf.keras.layers.Embedding(len(tokenizer.word_index)+1,32, input_length=7))
Model.add(tf.keras.layers.Dropout(0.5))
Model.add(tf.keras.layers.Conv1D(128,7, padding='same', activation='relu', strides=3))
Model.add(tf.keras.layers.Conv1D(128,7, padding='same', activation='relu', strides=3))
Model.add(tf.keras.layers.GlobalAveragePooling1D())
Model.add(tf.keras.layers.Dense(128, activation='relu'))
Model.add(tf.keras.layers.Dropout(0.5))
Model.add(tf.keras.layers.Dense(7, activation='softmax'))

# %%
print(Model.summary())
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_17 (Embedding)    (None, 7, 32)             1342464
#
#  dropout_8 (Dropout)         (None, 7, 32)             0
#
#  conv1d_10 (Conv1D)          (None, 3, 128)            28800
#
#  conv1d_11 (Conv1D)          (None, 1, 128)            114816
#
#  global_average_pooling1d_2   (None, 128)              0
#  (GlobalAveragePooling1D)
#
#  dense_25 (Dense)            (None, 128)               16512
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_26 (Dense)            (None, 7)                 903
#
# ...
# Total params: 1,503,495
# Trainable params: 1,503,495
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
Model.compile(loss=tf.keras.losses.sparse_categorical_crossentropy, optimizer='Adam', metrics='accuracy')

# %%
import numpy as np

# %%
sentiments =[x+1 for x in sentiments]
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(sentiments[:32000])
y_test = np.array(sentiments[32000:])

# %%
Model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1000/1000 [==============================] - 23s 23ms/step - loss: 1.7723 - accuracy: 0.2873 - val_loss: 1.6865 - val_accuracy: 0.3446
# Epoch 2/10
# 1000/1000 [==============================] - 20s 20ms/step - loss: 1.6379 - accuracy: 0.3658 - val_loss: 1.6763 - val_accuracy: 0.3532
# Epoch 3/10
# 1000/1000 [==============================] - 20s 20ms/step - loss: 1.5259 - accuracy: 0.4215 - val_loss: 1.7090 - val_accuracy: 0.3388
# Epoch 4/10
# 1000/1000 [==============================] - 19s 19ms/step - loss: 1.4216 - accuracy: 0.4604 - val_loss: 1.7556 - val_accuracy: 0.3373
# Epoch 5/10
# 1000/1000 [==============================] - 19s 19ms/step - loss: 1.3173 - accuracy: 0.5035 - val_loss: 1.8143 - val_accuracy: 0.3202
# Epoch 6/10
# 1000/1000 [==============================] - 21s 21ms/step - loss: 1.2365 - accuracy: 0.5388 - val_loss: 1.8510 - val_accuracy: 0.3266
# Epoch 7/10
# ...

# %%
test_pred=Model.predict(x_test)
# Out:
# 103/103 [==============================] - 0s 2ms/step

# %%
score=Model.evaluate(x_test,y_test,verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.2954823076725006

# %%
print(test_pred)
# Out:
# [[1.26118748e-03 2.22938936e-04 2.75556417e-03 ... 1.47250881e-02
#   2.85479631e-02 9.31979418e-01]
#  [2.73362100e-01 3.92834127e-01 1.73501030e-01 ... 4.32463624e-02
#   4.96233068e-02 2.89870072e-02]
#  [2.49231592e-01 7.45574653e-01 3.62590724e-03 ... 6.29110946e-05
#   9.30082402e-04 7.33626439e-05]
#  ...
#  [3.31148833e-01 2.15476468e-01 9.90892649e-02 ... 4.71140705e-02
#   6.94378093e-02 7.44408220e-02]
#  [1.24492206e-01 8.05804580e-02 9.44089592e-02 ... 5.99905327e-02
#   7.87385330e-02 1.76922619e-01]
#  [1.59687951e-01 1.23999365e-01 1.67782053e-01 ... 1.55211776e-01
#   1.07747212e-01 1.52324662e-01]]
